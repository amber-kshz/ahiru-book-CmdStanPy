# %%
import numpy as np
import pandas as pd
from cmdstanpy import CmdStanModel
from matplotlib import pyplot as plt

# %% [markdown]
# # Load and plot data

# %%
df = pd.read_csv("data/data-changepoint.txt")
print(len(df))
df.head(5)
# Out:
# 400
#    X     Y
# 0  1 -0.25
# 1  2  1.92
# 2  3 -0.57
# 3  4 -1.41
# 4  5 -0.90

# %%
plt.plot(df["X"], df["Y"])

# %% [markdown]
# # Run Stan

# %%
model = CmdStanModel(stan_file="model/model12-7.stan")
print(model)
# Out:
# INFO:cmdstanpy:compiling stan program, exe file: /workdir/chap12/model/model12-7
# INFO:cmdstanpy:compiler options: stanc_options=None, cpp_options=None
# INFO:cmdstanpy:compiled model file: /workdir/chap12/model/model12-7
# CmdStanModel: name=model12-7
# 	 stan_file=/workdir/chap12/model/model12-7.stan
# 	 exe_file=/workdir/chap12/model/model12-7
# 	 compiler_optons=stanc_options=None, cpp_options=None

# %%
data = {
    "T": len(df),
    "Y": df["Y"].values
}

# %%
fit = model.sample(data=data, show_progress=True)
# Out:
# Chain 1 - warmup:   0%|          | 0/1 [00:00<?, ?it/s]
# Chain 1 - warmup:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Chain 3 - warmup:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
# Chain 4 - warmup:   0%|          | 0/1 [00:00<?, ?it/s]
# Chain 2 - warmup:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Chain 3 - warmup:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
# Chain 4 - warmup:   0%|          | 0/1 [00:00<?, ?it/s]
# Chain 2 - warmup:   0%|          | 0/2000 [00:00<?, ?it/s]
#
#
# Chain 1 - warmup:   0%|          | 0/2000 [00:00<?, ?it/s]
#
# Chain 3 - warmup:   0%|          | 0/2000 [00:00<?, ?it/s]
#
# Chain 1 - warmup:   5%|▌         | 100/2000 [00:06<01:54, 16.57it/s]
#
#
# Chain 4 - warmup:   5%|▌         | 100/2000 [00:06<01:57, 16.19it/s]
# Chain 2 - warmup:   5%|▌         | 100/2000 [00:06<02:05, 15.19it/s]
#
# Chain 3 - warmup:  10%|█         | 200/2000 [00:10<01:37, 18.41it/s]
#
#
# Chain 4 - warmup:  10%|█         | 200/2000 [00:12<01:50, 16.22it/s]
# Chain 1 - warmup:  10%|█         | 200/2000 [00:12<01:51, 16.11it/s]
#
# Chain 3 - warmup:  15%|█▌        | 300/2000 [00:15<01:29, 18.91it/s]
#
#
# Chain 4 - warmup:  15%|█▌        | 300/2000 [00:16<01:35, 17.88it/s]
# Chain 1 - warmup:  15%|█▌        | 300/2000 [00:18<01:43, 16.39it/s]
#
#
# Chain 4 - warmup:  20%|██        | 400/2000 [00:20<01:19, 20.08it/s]
#
# Chain 3 - warmup:  20%|██        | 400/2000 [00:20<01:22, 19.34it/s]
# Chain 1 - warmup:  20%|██        | 400/2000 [00:23<01:33, 17.19it/s]
#
#
# Chain 4 - warmup:  25%|██▌       | 500/2000 [00:25<01:14, 20.10it/s]
#
# Chain 1 - warmup:  25%|██▌       | 500/2000 [00:27<01:20, 18.67it/s]
# Chain 2 - warmup:  25%|██▌       | 500/2000 [00:29<01:28, 17.04it/s]
#
#
# Chain 4 - warmup:  30%|███       | 600/2000 [00:30<01:09, 20.00it/s]
#
# Chain 1 - warmup:  30%|███       | 600/2000 [00:32<01:12, 19.40it/s]
# Chain 2 - warmup:  30%|███       | 600/2000 [00:33<01:17, 18.05it/s]
#
#
# Chain 4 - warmup:  35%|███▌      | 700/2000 [00:34<01:03, 20.46it/s]
#
# Chain 1 - warmup:  35%|███▌      | 700/2000 [00:37<01:05, 19.91it/s]
# Chain 2 - warmup:  35%|███▌      | 700/2000 [00:38<01:07, 19.35it/s]
#
#
# Chain 4 - warmup:  40%|████      | 800/2000 [00:38<00:55, 21.81it/s]
#
# Chain 1 - warmup:  40%|████      | 800/2000 [00:41<00:58, 20.50it/s]
# Chain 2 - warmup:  40%|████      | 800/2000 [00:42<00:58, 20.47it/s]
#
#
# Chain 4 - warmup:  45%|████▌     | 900/2000 [00:42<00:49, 22.30it/s]
#
# Chain 1 - warmup:  45%|████▌     | 900/2000 [00:45<00:51, 21.56it/s]
# Chain 2 - warmup:  45%|████▌     | 900/2000 [00:46<00:51, 21.22it/s]
#
#
# Chain 4 - warmup:  50%|█████     | 1000/2000 [00:48<00:47, 21.10it/s]
#
#
# Chain 4 - sample:  50%|█████     | 1000/2000 [00:48<00:47, 21.10it/s]
#
# Chain 3 - warmup:  50%|█████     | 1000/2000 [00:48<00:45, 21.83it/s]
#
# Chain 1 - sample:  50%|█████     | 1000/2000 [00:51<00:48, 20.61it/s]
# Chain 2 - warmup:  50%|█████     | 1000/2000 [00:52<00:49, 20.25it/s]
# Chain 2 - sample:  50%|█████     | 1000/2000 [00:52<00:49, 20.25it/s]
#
# Chain 3 - sample:  55%|█████▌    | 1100/2000 [00:56<00:49, 18.30it/s]
#
#
# Chain 1 - sample:  55%|█████▌    | 1100/2000 [00:59<00:52, 17.22it/s]
# Chain 2 - sample:  55%|█████▌    | 1100/2000 [01:00<00:52, 17.15it/s]
#
# Chain 3 - sample:  60%|██████    | 1200/2000 [01:03<00:47, 16.92it/s]
#
#
# Chain 1 - sample:  60%|██████    | 1200/2000 [01:07<00:52, 15.35it/s]
# Chain 2 - sample:  60%|██████    | 1200/2000 [01:07<00:51, 15.61it/s]
#
# Chain 3 - sample:  65%|██████▌   | 1300/2000 [01:10<00:44, 15.67it/s]
#
#
# Chain 1 - sample:  65%|██████▌   | 1300/2000 [01:15<00:48, 14.31it/s]
# Chain 2 - sample:  65%|██████▌   | 1300/2000 [01:15<00:47, 14.64it/s]
#
# Chain 3 - sample:  70%|███████   | 1400/2000 [01:18<00:40, 14.88it/s]
#
#
# Chain 4 - sample:  70%|███████   | 1400/2000 [01:20<00:43, 13.67it/s]
# Chain 1 - sample:  70%|███████   | 1400/2000 [01:23<00:44, 13.60it/s]
#
# Chain 3 - sample:  75%|███████▌  | 1500/2000 [01:25<00:34, 14.48it/s]
#
#
# Chain 4 - sample:  75%|███████▌  | 1500/2000 [01:28<00:37, 13.20it/s]
# Chain 1 - sample:  75%|███████▌  | 1500/2000 [01:31<00:37, 13.29it/s]
#
# Chain 3 - sample:  80%|████████  | 1600/2000 [01:32<00:28, 14.26it/s]
#
#
# Chain 4 - sample:  80%|████████  | 1600/2000 [01:37<00:30, 12.91it/s]
# Chain 2 - sample:  80%|████████  | 1600/2000 [01:39<00:29, 13.42it/s]
#
# Chain 1 - sample:  80%|████████  | 1600/2000 [01:39<00:30, 13.03it/s]
#
#
# Chain 4 - sample:  85%|████████▌ | 1700/2000 [01:45<00:23, 12.77it/s]
# Chain 2 - sample:  85%|████████▌ | 1700/2000 [01:46<00:22, 13.24it/s]
#
# Chain 1 - sample:  85%|████████▌ | 1700/2000 [01:47<00:23, 12.89it/s]
#
#
# Chain 4 - sample:  90%|█████████ | 1800/2000 [01:53<00:15, 12.63it/s]
#
# Chain 3 - sample:  95%|█████████▌| 1900/2000 [01:53<00:07, 14.17it/s]
# Chain 1 - sample:  90%|█████████ | 1800/2000 [01:55<00:15, 12.80it/s]
#
#
# Chain 4 - sample:  95%|█████████▌| 1900/2000 [02:01<00:07, 12.53it/s]
#
# Chain 3 - sample: 100%|██████████| 2000/2000 [02:01<00:00, 13.84it/s]
#
# Chain 3 -   done: 100%|██████████| 2000/2000 [02:01<00:00, 13.84it/s]
# Chain 1 - sample:  95%|█████████▌| 1900/2000 [02:03<00:07, 12.80it/s]
#
#
# Chain 4 - sample: 100%|██████████| 2000/2000 [02:08<00:00, 12.77it/s]
#
#
# Chain 4 -   done: 100%|██████████| 2000/2000 [02:08<00:00, 12.77it/s]
# Chain 2 - sample: 100%|██████████| 2000/2000 [02:09<00:00, 13.40it/s]
# Chain 1 -   done: 100%|██████████| 2000/2000 [02:10<00:00, 15.32it/s]
# Chain 2 -   done: 100%|██████████| 2000/2000 [02:10<00:00, 15.31it/s]
# Chain 3 -   done: 100%|██████████| 2000/2000 [02:10<00:00, 15.33it/s]
# Chain 4 -   done: 100%|██████████| 2000/2000 [02:10<00:00, 15.32it/s]

# %%
summary = fit.summary()
summary[summary["R_hat"] >= 1.1]
# Out:
# Empty DataFrame
# Columns: [Mean, MCSE, StdDev, 5%, 50%, 95%, N_Eff, N_Eff/s, R_hat]
# Index: []

# %% [markdown]
# # Plot result

# %%
mu_percentiles = np.percentile(fit.stan_variable("mu"), [2.5, 25.0, 50.0, 75.0, 97.5], axis=0)

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(1, 1, 1)

ax.plot(df["X"].values, df["Y"].values, color='grey', linewidth=1)
ax.fill_between(df["X"].values, mu_percentiles[0], mu_percentiles[4], color='k', alpha=0.3)
ax.fill_between(df["X"].values, mu_percentiles[1], mu_percentiles[3], color='k', alpha=0.6)
ax.plot(df["X"].values, mu_percentiles[2], color="k", linewidth=2)
ax.set_xlabel("time (second)")
ax.set_ylabel("Y")
fig.show()
