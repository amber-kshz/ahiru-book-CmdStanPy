# %%
import numpy as np
import pandas as pd
from cmdstanpy import CmdStanModel
from matplotlib import pyplot as plt

# %% [markdown]
# # Load and plot data

# %%
Y = np.genfromtxt("data/data-2Dmesh.txt", delimiter=",")
TID = np.genfromtxt("data/data-2Dmesh-design.txt", delimiter=",", dtype="int")

# %%
Y.shape, TID.shape
# Out:
# ((16, 24), (16, 24))

# %%
# Fig 12.8
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot()
ax.set_xlabel("Plate Column")
ax.set_ylabel("Plate Row")
fig.colorbar(ax.imshow(Y))
fig.show()

# %% [markdown]
# # Run stan

# %%
#model= CmdStanModel(stan_file="model/model12-13.stan")
model= CmdStanModel(stan_file="model/model12-13b.stan")
print(model)
# Out:
# INFO:cmdstanpy:compiling stan program, exe file: /workdir/chap12/model/model12-13b
# INFO:cmdstanpy:compiler options: stanc_options=None, cpp_options=None
# INFO:cmdstanpy:compiled model file: /workdir/chap12/model/model12-13b
# CmdStanModel: name=model12-13b
# 	 stan_file=/workdir/chap12/model/model12-13b.stan
# 	 exe_file=/workdir/chap12/model/model12-13b
# 	 compiler_optons=stanc_options=None, cpp_options=None

# %%
I = Y.shape[0] # 16
J = Y.shape[1] # 24
T = 96

data = {
    "I": I,
    "J": J,
    "Y": Y,
    "T": T,
    "TID": TID
}

# %%
fit = model.sample(data=data)
# Out:
# INFO:cmdstanpy:start chain 1
# INFO:cmdstanpy:start chain 2
# INFO:cmdstanpy:start chain 3
# INFO:cmdstanpy:start chain 4
# INFO:cmdstanpy:finish chain 3
# INFO:cmdstanpy:finish chain 4
# INFO:cmdstanpy:finish chain 2
# INFO:cmdstanpy:finish chain 1

# %%
summary = fit.summary()
summary[summary["R_hat"] >= 1.1]
# Out:
# Empty DataFrame
# Columns: [Mean, MCSE, StdDev, 5%, 50%, 95%, N_Eff, N_Eff/s, R_hat]
# Index: []

# %% [markdown]
# # Plot result

# %%
# Figure 12.9 left
r_median = np.median(fit.stan_variable("r"), axis=0)

y = np.arange(1, 25, 1)
x = np.arange(1, 17, 1)
x, y = np.meshgrid(x, y)

fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(projection="3d", azim=-30, elev=30)
ax.plot_surface(x, y, r_median.transpose(), cmap="viridis")
ax.set_xlabel("Plate Row")
ax.set_ylabel("Plate Column")
ax.set_zlabel("r")
fig.show()

# %%
# Figure 12.9 right

Y_mean = Y.mean()
Y_t = np.zeros(T)
count_t = np.zeros(T)
for i in range(I):
    for j in range(J):
        Y_t[TID[i,j]-1] += Y[i,j]
        count_t[TID[i,j]-1] += 1        
for t in range(T):
    Y_t[t] = Y_t[t] / count_t[t] - Y_mean
    
beta_percentiles = np.percentile(fit.stan_variable("beta"), [2.5, 50.0, 97.5], axis=0)

fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot()
ax.plot([-5.0, 5.0], [-5.0, 5.0], "k--")
ax.errorbar(
    x=Y_t, 
    y=beta_percentiles[1], 
    yerr=np.abs(beta_percentiles[[0, 2]] - beta_percentiles[1]),
    fmt="o",
    ecolor='k',
    markerfacecolor='w',
    markeredgecolor='k',
    markersize=10
)
ax.set_xlim(-5.5, 5.5)
ax.set_ylim(-5.5, 5.5)
ax.set_aspect("equal")
ax.set_xlabel("Mean of Y[TID]")
ax.set_ylabel("beta[t]")
fig.show()
