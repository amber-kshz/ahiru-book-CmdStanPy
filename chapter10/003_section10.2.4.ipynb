# %%
import numpy as np
import pandas as pd
from cmdstanpy import CmdStanModel

# %%
df = pd.read_csv("../chapter08/data/data-salary-2.txt")
print(len(df))
df.head(5)
# Out:
# 40
#     X    Y  KID
# 0   7  457    1
# 1  10  482    1
# 2  16  518    1
# 3  25  535    1
# 4   5  427    1

# %%
data = {
    "N": len(df),
    "K": len(set(df["KID"].values)),
    "X": df["X"].values,
    "Y": df["Y"].values,
    "KID": df["KID"].values
}

# %% [markdown]
# # Model 10-5

# %%
model10_5 = CmdStanModel(stan_file="model/model10-5.stan")
print(model10_5)
# Out:
# INFO:cmdstanpy:compiling stan program, exe file: /workdir/chapter10/model/model10-5
# INFO:cmdstanpy:compiler options: stanc_options=None, cpp_options=None
# INFO:cmdstanpy:compiled model file: /workdir/chapter10/model/model10-5
# CmdStanModel: name=model10-5
# 	 stan_file=/workdir/chapter10/model/model10-5.stan
# 	 exe_file=/workdir/chapter10/model/model10-5
# 	 compiler_optons=stanc_options=None, cpp_options=None

# %%
fit10_5 = model10_5.sample(data=data, show_progress=True)
# Out:
# ...
# Chain 1 - warmup:   0%|          | 0/1 [00:00<?, ?it/s]
#
# ...
# Chain 2 - warmup:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
# ...
# Chain 2 - warmup:   0%|          | 0/2000 [00:00<?, ?it/s]
#
# Chain 3 - warmup:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Chain 3 - warmup:   0%|          | 0/2000 [00:00<?, ?it/s]
#
#
# Chain 4 - warmup:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
# ...
# Chain 2 - warmup:   5%|▌         | 100/2000 [00:00<00:12, 146.39it/s]
#
# Chain 3 - warmup:   5%|▌         | 100/2000 [00:00<00:12, 146.66it/s]
#
#
# ...
# Chain 1 - warmup:  10%|█         | 200/2000 [00:00<00:09, 181.52it/s]
#
# Chain 3 - warmup:  10%|█         | 200/2000 [00:01<00:10, 169.47it/s]
#
#
# ...
# Chain 2 - warmup:  15%|█▌        | 300/2000 [00:01<00:08, 195.00it/s]
#
# Chain 3 - warmup:  15%|█▌        | 300/2000 [00:01<00:10, 163.88it/s]
#
#
# ...
# Chain 1 - warmup:  20%|██        | 400/2000 [00:01<00:08, 186.39it/s]
#
# ...
# Chain 2 - warmup:  25%|██▌       | 500/2000 [00:02<00:08, 186.37it/s]
#
#
# ...

# %%
fit10_5.summary()
# Out:
#                   Mean          MCSE        StdDev            5%  \
# name
# lp__     -1.720340e+02  1.941430e+00  4.150090e+00 -1.794930e+02
# ab[1,1]   3.900000e+02  1.800000e+00  1.300000e+01  3.670000e+02
# ab[1,2]   7.300000e+00  2.300000e-01  8.500000e-01  6.100000e+00
# ab[2,1]   3.260000e+02  1.100000e+00  1.300000e+01  3.040000e+02
# ab[2,2]   2.000000e+01  1.200000e-01  9.400000e-01  1.900000e+01
# ab[3,1]   3.130000e+02  4.800000e+00  3.200000e+01  2.550000e+02
# ab[3,2]   1.200000e+01  2.400000e-01  1.600000e+00  9.900000e+00
# ab[4,1]   7.160000e+02  2.000000e+01  1.590000e+02  4.740000e+02
# ab[4,2]   4.500000e-01  8.100000e-01  6.400000e+00 -1.200000e+01
# ab0[1]    5.177810e+05  4.562900e+05  1.184975e+06 -5.303800e+05
# ab0[2]    1.682000e+03  1.240600e+04  3.200500e+04 -5.168200e+04
# cov[1,1]  3.578932e+16  1.252737e+16  6.304623e+17  4.120770e+10
# cov[1,2] -3.022806e+14  3.283678e+14  5.476748e+14 -1.075110e+15
# ...

# %% [markdown]
# `R_hat`の値から、収束していないことがわかる。

# %% [markdown]
# # Model 10-6

# %%
model10_6 = CmdStanModel(stan_file="model/model10-6.stan")
print(model10_6)
# Out:
# INFO:cmdstanpy:compiling stan program, exe file: /workdir/chapter10/model/model10-6
# INFO:cmdstanpy:compiler options: stanc_options=None, cpp_options=None
# INFO:cmdstanpy:compiled model file: /workdir/chapter10/model/model10-6
# CmdStanModel: name=model10-6
# 	 stan_file=/workdir/chapter10/model/model10-6.stan
# 	 exe_file=/workdir/chapter10/model/model10-6
# 	 compiler_optons=stanc_options=None, cpp_options=None

# %%
fit10_6 = model10_6.sample(data=data, show_progress=True)
# Out:
# ...
# Chain 1 - warmup:   0%|          | 0/1 [00:00<?, ?it/s]
#
# ...
# Chain 2 - warmup:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
# ...
# Chain 2 - warmup:   0%|          | 0/2000 [00:00<?, ?it/s]
#
# Chain 3 - warmup:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Chain 3 - warmup:   0%|          | 0/2000 [00:00<?, ?it/s]
#
#
# Chain 4 - warmup:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
# Chain 4 - warmup:   0%|          | 0/2000 [00:00<?, ?it/s]
#
# ...
# Chain 2 - warmup:   5%|▌         | 100/2000 [00:00<00:09, 204.31it/s]
#
# Chain 3 - warmup:  15%|█▌        | 300/2000 [00:00<00:04, 377.41it/s]
#
#
# ...
# Chain 1 - warmup:  15%|█▌        | 300/2000 [00:00<00:06, 279.93it/s]
#
# Chain 3 - warmup:  30%|███       | 600/2000 [00:00<00:02, 498.72it/s]
#
#
# ...
# Chain 2 - warmup:  30%|███       | 600/2000 [00:00<00:03, 375.14it/s]
#
# Chain 3 - warmup:  45%|████▌     | 900/2000 [00:00<00:01, 652.90it/s]
#
#
# Chain 1 - warmup:  35%|███▌      | 700/2000 [00:00<00:02, 490.14it/s]
#
# ...

# %%
summary10_6 = fit10_6.summary()
summary10_6[summary10_6["R_hat"] >= 1.1]
# Out:
# Empty DataFrame
# Columns: [Mean, MCSE, StdDev, 5%, 50%, 95%, N_Eff, N_Eff/s, R_hat]
# Index: []

# %%
summary10_6
# Out:
#                Mean        MCSE      StdDev       5%       50%        95%  \
# name
# lp__       -173.014    0.120428      3.3635  -179.07  -172.722   -167.922
# ab[1,1]     383.000    0.340000     15.0000   358.00   382.000    408.000
# ab[1,2]       7.800    0.022000      0.9500     6.20     7.800      9.300
# ab[2,1]     335.000    0.500000     19.0000   305.00   335.000    367.000
# ab[2,2]      19.000    0.036000      1.4000    17.00    19.000     22.000
# ab[3,1]     331.000    0.960000     34.0000   271.00   333.000    383.000
# ab[3,2]      12.000    0.045000      1.7000     9.10    12.000     15.000
# ab[4,1]     437.000    4.000000    115.0000   314.00   400.000    671.000
# ab[4,2]      12.000    0.160000      4.6000     1.90    13.000     17.000
# ab0[1]      372.000    1.600000     59.0000   296.00   365.000    478.000
# ab0[2]       13.000    0.120000      4.6000     5.40    13.000     20.000
# s_a          91.900    2.800000     79.3000    13.00    67.800    248.200
# ...

# %% [markdown]
# # Model 10-7

# %%
data["Nu"] = 2

# %%
model10_7 = CmdStanModel(stan_file="model/model10-7.stan")
print(model10_7)
# Out:
# INFO:cmdstanpy:compiling stan program, exe file: /workdir/chapter10/model/model10-7
# INFO:cmdstanpy:compiler options: stanc_options=None, cpp_options=None
# INFO:cmdstanpy:compiled model file: /workdir/chapter10/model/model10-7
# CmdStanModel: name=model10-7
# 	 stan_file=/workdir/chapter10/model/model10-7.stan
# 	 exe_file=/workdir/chapter10/model/model10-7
# 	 compiler_optons=stanc_options=None, cpp_options=None

# %%
fit10_7 = model10_7.sample(data=data, show_progress=True)
# Out:
# ...
# Chain 1 - warmup:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Chain 3 - warmup:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
# ...
# Chain 2 - warmup:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Chain 3 - warmup:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
# ...
# Chain 2 - warmup:   0%|          | 0/2000 [00:00<?, ?it/s]
#
# Chain 3 - warmup:   0%|          | 0/2000 [00:00<?, ?it/s]
#
#
# Chain 4 - warmup:   0%|          | 0/2000 [00:00<?, ?it/s]
#
# ...
# Chain 2 - warmup:   5%|▌         | 100/2000 [00:00<00:09, 208.94it/s]
#
# Chain 3 - warmup:  15%|█▌        | 300/2000 [00:00<00:05, 339.20it/s]
#
#
# ...
# Chain 2 - warmup:  15%|█▌        | 300/2000 [00:00<00:06, 283.11it/s]
#
# Chain 3 - warmup:  25%|██▌       | 500/2000 [00:00<00:03, 451.24it/s]
#
#
# ...
# Chain 2 - warmup:  25%|██▌       | 500/2000 [00:00<00:03, 379.82it/s]
#
# Chain 3 - warmup:  40%|████      | 800/2000 [00:00<00:02, 597.40it/s]
#
#
# ...
# Chain 1 - warmup:  30%|███       | 600/2000 [00:00<00:04, 304.15it/s]
#
# ...

# %%
summary10_7 = fit10_7.summary()
summary10_7[summary10_7["R_hat"] >= 1.1]
# Out:
# Empty DataFrame
# Columns: [Mean, MCSE, StdDev, 5%, 50%, 95%, N_Eff, N_Eff/s, R_hat]
# Index: []

# %%
summary10_7
# Out:
#                      Mean        MCSE        StdDev        5%       50%  \
# name
# lp__             -172.654    0.109091  3.227190e+00  -178.498  -172.338
# ab[1,1]           382.000    0.380000  1.500000e+01   357.000   383.000
# ab[1,2]             7.800    0.024000  9.500000e-01     6.300     7.800
# ab[2,1]           336.000    0.550000  1.800000e+01   307.000   336.000
# ab[2,2]            19.000    0.038000  1.300000e+00    17.000    19.000
# ab[3,1]           329.000    0.900000  3.300000e+01   272.000   330.000
# ab[3,2]            12.000    0.043000  1.600000e+00     9.300    12.000
# ab[4,1]           440.000    3.900000  1.120000e+02   315.000   408.000
# ab[4,2]            11.000    0.160000  4.500000e+00     2.000    13.000
# ab0[1]            373.000    1.400000  5.700000e+01   297.000   366.000
# ab0[2]             13.000    0.098000  4.400000e+00     5.100    13.000
# corr_chol[1,1]      1.000         NaN  6.000000e-16     1.000     1.000
# ...
