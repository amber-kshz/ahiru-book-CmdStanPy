# %%
import pandas as pd
from cmdstanpy import CmdStanModel

# %%
df = pd.read_csv("../chapter08/data/data-salary-2.txt")
print(len(df))
df.head(5)
# Out:
# 40
#     X    Y  KID
# 0   7  457    1
# 1  10  482    1
# 2  16  518    1
# 3  25  535    1
# 4   5  427    1

# %%
data = {
    "N": len(df),
    "K": 4,
    "X": df["X"].values,
    "Y": df["Y"].values,
    "KID": df["KID"].values
}

# %% [markdown]
# # Model 8-4b

# %%
model8_4b = CmdStanModel(stan_file="../chapter09/model/model8-4b.stan")
print(model8_4b)
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling
# INFO:cmdstanpy:compiled model file: /workdir/chapter09/model/model8-4b
# CmdStanModel: name=model8-4b
# 	 stan_file=/workdir/chapter09/model/model8-4b.stan
# 	 exe_file=/workdir/chapter09/model/model8-4b
# 	 compiler_optons=stanc_options=None, cpp_options=None

# %%
fit8_4b = model8_4b.sample(data=data)
# Out:
# INFO:cmdstanpy:start chain 1
# INFO:cmdstanpy:start chain 4
# INFO:cmdstanpy:start chain 3
# INFO:cmdstanpy:start chain 2
# INFO:cmdstanpy:finish chain 4
# INFO:cmdstanpy:finish chain 1
# INFO:cmdstanpy:finish chain 2
# INFO:cmdstanpy:finish chain 3

# %%
fit8_4b.summary()
# Out:
#           Mean      MCSE     StdDev         5%       50%       95%     N_Eff  \
# name
# lp__ -173.0200  0.229038    3.56251 -179.49800 -172.6710 -167.6400   241.934
# a0    375.9770  3.819240  119.84200  245.31000  367.4590  554.6730   984.615
# b0     11.5096  0.686355   13.66580    1.87748   12.3099   21.3194   396.437
# a[1]  383.0000  0.500000   15.00000  359.00000  383.0000  408.0000   912.000
# a[2]  336.0000  0.810000   19.00000  306.00000  335.0000  365.0000   523.000
# a[3]  327.0000  0.840000   33.00000  271.00000  328.0000  378.0000  1551.000
# a[4]  479.0000  4.800000  134.00000  321.00000  445.0000  734.0000   796.000
# b[1]    7.8000  0.041000    0.94000    6.20000    7.7000    9.3000   520.000
# b[2]   19.0000  0.052000    1.40000   17.00000   19.0000   22.0000   703.000
# b[3]   12.0000  0.040000    1.60000    9.20000   12.0000   15.0000  1620.000
# b[4]    9.9000  0.190000    5.40000   -0.39000   11.0000   16.0000   826.000
# ...

# %% [markdown]
# # Model 8-4c

# %%
model8_4c = CmdStanModel(stan_file="model/model8-4c.stan")
print(model8_4c)
# Out:
# INFO:cmdstanpy:compiling stan program, exe file: /workdir/chapter10/model/model8-4c
# INFO:cmdstanpy:compiler options: stanc_options=None, cpp_options=None
# INFO:cmdstanpy:compiled model file: /workdir/chapter10/model/model8-4c
# CmdStanModel: name=model8-4c
# 	 stan_file=/workdir/chapter10/model/model8-4c.stan
# 	 exe_file=/workdir/chapter10/model/model8-4c
# 	 compiler_optons=stanc_options=None, cpp_options=None

# %%
fit8_4c = model8_4c.sample(data=data)
# Out:
# INFO:cmdstanpy:start chain 1
# INFO:cmdstanpy:start chain 2
# INFO:cmdstanpy:start chain 3
# INFO:cmdstanpy:start chain 4
# INFO:cmdstanpy:finish chain 3
# INFO:cmdstanpy:finish chain 1
# INFO:cmdstanpy:finish chain 2
# INFO:cmdstanpy:finish chain 4

# %%
fit8_4c.summary()
# Out:
#              Mean      MCSE     StdDev         5%       50%       95%  \
# name
# lp__     -146.802  0.266460    4.18794 -154.52000 -146.4350 -140.5300
# a0        375.465  2.922150   76.11960  271.58600  366.5350  513.4380
# b0         12.900  0.596753    6.76643    3.72225   12.5162   23.8636
# a_raw[1]    0.220  0.032000    0.70000   -0.87000    0.1800    1.5000
# a_raw[2]   -0.420  0.017000    0.62000   -1.50000   -0.3900    0.5700
# a_raw[3]   -0.480  0.029000    0.70000   -1.60000   -0.4700    0.6300
# a_raw[4]    0.670  0.037000    0.88000   -0.84000    0.6900    2.1000
# b_raw[1]   -0.670  0.026000    0.64000   -1.70000   -0.6500    0.3300
# b_raw[2]    0.950  0.044000    0.77000   -0.31000    0.9400    2.3000
# b_raw[3]   -0.092  0.032000    0.61000   -1.10000   -0.0900    0.9000
# b_raw[4]   -0.210  0.025000    0.68000   -1.30000   -0.2000    0.9000
# s_a       120.600  5.700000  115.20000   14.00000   84.2000  339.5000
# ...

# %% [markdown]
# 注 : こちらの方が収束しなかった例もあった。
